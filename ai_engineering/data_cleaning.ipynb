# %% [markdown]
# # Data Cleaning
# This notebook has the purpose to clean some data entries which are not accurate enough for our usage.
# After talking to the data owener (WSL institution) we got the information, that some damages are mapped to the canton, when there are no accurate data.
# As these are only 11 data entries, we decided to not consider them.

# %%
import pandas as pd

# %%
df = pd.read_excel('Data/USDB_1972_2023_ohneSchadenszahlen_ohneBeschriebe_original.xlsx')
df
# Out:
#              Gemeinde Gemeindenummer Weitere Gemeinde     Kanton  \
# 0          Rossinière           5842              NaN  VD_x001D_
# 1           Sonvilier            445              NaN  BE_x001D_
# 2      Ormont-Dessous           5410              NaN  VD_x001D_
# 3          Einsiedeln           1301              NaN  SZ_x001D_
# 4              Nendaz           6024              NaN  VS_x001D_
# ...               ...            ...              ...        ...
# 28510       Innerthal           1343              NaN  SZ_x001D_
# 28511            Belp            861           Toffen  BE_x001D_
# 28512          Toffen            884              NaN  BE_x001D_
# 28513        Zollikon            161              NaN  ZH_x001D_
# 28514         Tschlin           3753              NaN  GR_x001D_
#
#            Prozessraum MAXO Datum      Datum MAXO Zeit      Zeit Gewässer  \
# 0      Pont du Lanciau          A 1972-02-17         A  01:00:00      NaN
# 1                  NaN          A 1972-03-09         A  01:00:00      NaN
# 2                  NaN          M 1972-04-08         M  20:30:00      NaN
# 3              Miesegg          A 1972-05-01         O       NaN      NaN
# 4         Les Follards          M 1972-06-16         O       NaN      NaN
# ...                ...        ...        ...       ...       ...      ...
# 28510        Gugelberg          A 2023-12-17         A  01:30:00      NaN
# 28511              NaN          M 2023-12-18       NaN       NaN      NaN
# 28512        Breitlohn          M 2023-12-19         M  14:30:00      NaN
# 28513   Trichtenhausen          M 2023-12-22       NaN       NaN      NaN
# 28514           Vinadi          M 2023-12-23         M  06:00:00      NaN
#
#        ... Gewitter Niederschlagsmenge [mm] Dauerregen Dauer MAXO  \
# 0      ...                              NaN                   NaN
# 1      ...                              NaN                   NaN
# 2      ...                              NaN                   NaN
# 3      ...                              NaN                   NaN
# 4      ...                              NaN                   NaN
# ...    ...                              ...                   ...
# 28510  ...                              NaN                     O
# 28511  ...                              NaN                     O
# 28512  ...                              NaN                     O
# 28513  ...                              NaN                     O
# 28514  ...                              NaN                     O
#
#       Dauerregen Dauer [Std.] Dauerregen Niederschlagsmenge MAXO  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
# ...                       ...                                ...
# 28510                     NaN                                  O
# 28511                     NaN                                  O
# 28512                     NaN                                  O
# 28513                     NaN                                  O
# 28514                     NaN                                  O
#
#       Dauerregen Niederschlagsmenge [mm] Schneeschmelze MAXO Schneeschmelze   \
# 0                                    NaN                 NaN             NaN
# 1                                    NaN                 NaN             NaN
# 2                                    NaN                 NaN             NaN
# 3                                    NaN                 NaN             NaN
# 4                                    NaN                 NaN             NaN
# ...                                  ...                 ...             ...
# 28510                                NaN                 NaN             NaN
# 28511                                NaN                   M             1.0
# 28512                                NaN                 NaN             NaN
# 28513                                NaN                 NaN             NaN
# 28514                                NaN                 NaN             NaN
#
#        Ursache nicht bestimmbar MAXO Ursache nicht bestimmbar      ID
# 0                                  M                       1.0  37955
# 1                                  M                       1.0  37619
# 2                                  M                       1.0  37956
# 3                                NaN                       NaN  10498
# 4                                  M                       1.0  37600
# ...                              ...                       ...    ...
# 28510                            NaN                       NaN  39138
# 28511                            NaN                       NaN  39159
# 28512                            NaN                       NaN  39157
# 28513                            NaN                       NaN  39201
# 28514                            NaN                       NaN  39199
#
# [28515 rows x 33 columns]

# %%
# the "Gemenide" column begins with "Kt." if we want to delete it.
rows_to_delete = df[df['Gemeinde'].str.startswith('Kt.')].index
deleted_wrong_rows = df.drop(rows_to_delete)
deleted_wrong_rows
# Out:
#              Gemeinde Gemeindenummer Weitere Gemeinde     Kanton  \
# 0          Rossinière           5842              NaN  VD_x001D_
# 1           Sonvilier            445              NaN  BE_x001D_
# 2      Ormont-Dessous           5410              NaN  VD_x001D_
# 3          Einsiedeln           1301              NaN  SZ_x001D_
# 4              Nendaz           6024              NaN  VS_x001D_
# ...               ...            ...              ...        ...
# 28510       Innerthal           1343              NaN  SZ_x001D_
# 28511            Belp            861           Toffen  BE_x001D_
# 28512          Toffen            884              NaN  BE_x001D_
# 28513        Zollikon            161              NaN  ZH_x001D_
# 28514         Tschlin           3753              NaN  GR_x001D_
#
#            Prozessraum MAXO Datum      Datum MAXO Zeit      Zeit Gewässer  \
# 0      Pont du Lanciau          A 1972-02-17         A  01:00:00      NaN
# 1                  NaN          A 1972-03-09         A  01:00:00      NaN
# 2                  NaN          M 1972-04-08         M  20:30:00      NaN
# 3              Miesegg          A 1972-05-01         O       NaN      NaN
# 4         Les Follards          M 1972-06-16         O       NaN      NaN
# ...                ...        ...        ...       ...       ...      ...
# 28510        Gugelberg          A 2023-12-17         A  01:30:00      NaN
# 28511              NaN          M 2023-12-18       NaN       NaN      NaN
# 28512        Breitlohn          M 2023-12-19         M  14:30:00      NaN
# 28513   Trichtenhausen          M 2023-12-22       NaN       NaN      NaN
# 28514           Vinadi          M 2023-12-23         M  06:00:00      NaN
#
#        ... Gewitter Niederschlagsmenge [mm] Dauerregen Dauer MAXO  \
# 0      ...                              NaN                   NaN
# 1      ...                              NaN                   NaN
# 2      ...                              NaN                   NaN
# 3      ...                              NaN                   NaN
# 4      ...                              NaN                   NaN
# ...    ...                              ...                   ...
# 28510  ...                              NaN                     O
# 28511  ...                              NaN                     O
# 28512  ...                              NaN                     O
# 28513  ...                              NaN                     O
# 28514  ...                              NaN                     O
#
#       Dauerregen Dauer [Std.] Dauerregen Niederschlagsmenge MAXO  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
# ...                       ...                                ...
# 28510                     NaN                                  O
# 28511                     NaN                                  O
# 28512                     NaN                                  O
# 28513                     NaN                                  O
# 28514                     NaN                                  O
#
#       Dauerregen Niederschlagsmenge [mm] Schneeschmelze MAXO Schneeschmelze   \
# 0                                    NaN                 NaN             NaN
# 1                                    NaN                 NaN             NaN
# 2                                    NaN                 NaN             NaN
# 3                                    NaN                 NaN             NaN
# 4                                    NaN                 NaN             NaN
# ...                                  ...                 ...             ...
# 28510                                NaN                 NaN             NaN
# 28511                                NaN                   M             1.0
# 28512                                NaN                 NaN             NaN
# 28513                                NaN                 NaN             NaN
# 28514                                NaN                 NaN             NaN
#
#        Ursache nicht bestimmbar MAXO Ursache nicht bestimmbar      ID
# 0                                  M                       1.0  37955
# 1                                  M                       1.0  37619
# 2                                  M                       1.0  37956
# 3                                NaN                       NaN  10498
# 4                                  M                       1.0  37600
# ...                              ...                       ...    ...
# 28510                            NaN                       NaN  39138
# 28511                            NaN                       NaN  39159
# 28512                            NaN                       NaN  39157
# 28513                            NaN                       NaN  39201
# 28514                            NaN                       NaN  39199
#
# [28395 rows x 33 columns]

# %%
# safe to excel
deleted_wrong_rows.to_excel('Data/USDB_1972_2023_ohneSchadenszahlen_ohneBeschriebe.xlsx')
